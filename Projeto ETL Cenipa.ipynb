# %% [markdown]
# #### PROJETO ETL - PYTHON ( Extração - Transformação - Carregamento de dados)
# *Etapas Extração - Validação - Limpeza -Transformação - carregamento de Dados*
#
# 1 - <b>Extract:</b> Os dados são extraidos de diferentes fontes de dados.
#
# 2 - <b>Transform:</b> Propagados para área de preparação de dados, onde são transformados e limpos.
#
# 3 - <b>Load:</b> Carregados no data Warehouse - Cluster Hadoop
#
# ##### Ferramentas ETL: Apache Airflow, pacote luigi, bonobo, bubbles, petl, pandas
#
# ### OCORRÊNCIA AERONAUTICA NA AVIAÇÃO BRASILEIRA CENIPA
#
# * FONTE DADOS: http://sistema.cenipa.aer.mil.br/cenipa/media/opendata/ocorrencia.csv

# %% [markdown]
# ### 1º Extração dos dados

# %%
import pandas as pd
import pandera as pa
#pandas por padrão o separador é (,) então precisamos passar parametro (sep=;) pois a planilha está com ;
# parse_dates = converter o campo em data
#dayfirst = colocar a data em primeiro pois no pandas é em ultimo padrao americano
df = pd.read_csv("ocorrencia.csv",nrows=2000, sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)

# %%
# primeiras 10 linhas .head ultimas .tail
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
# 5              39807               39807               39807
# 6              40215               40215               40215
# 7              39707               39707               39707
# 8              39156               39156               39156
# 9              39711               39711               39711
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
# 5               39807               39807                INCIDENTE
# 6               40215               40215                INCIDENTE
# 7               39707               39707          INCIDENTE GRAVE
# 8               39156               39156          INCIDENTE GRAVE
# 9               39711               39711          INCIDENTE GRAVE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# 1                 NaN                  NaN               BELÉM            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE            MT
# 4                 NaN                  NaN             PELOTAS            RS
# 5                 ***                  ***            SALVADOR            BA
# 6                 ***                  ***               COARI            AM
# 7       -6.5319444444       -64.3805555556            CANUTAMA            AM
# 8      -15.2402777778       -59.3541666667            CASCAVEL            PR
# 9                 ***                  ***       PARÁ DE MINAS            MG
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  ...     2010-01-03        12:00:00                            SIM
# 1  ...     2010-01-03        11:05:00                            SIM
# 2  ...     2010-01-03        03:00:00                            SIM
# 3  ...     2010-01-04        17:30:00                            SIM
# 4  ...     2010-01-05        19:25:00                            SIM
# 5  ...     2010-01-06        17:53:00                            ***
# 6  ...     2010-01-07        18:40:00                            SIM
# 7  ...     2010-01-09        12:30:00                            SIM
# 8  ...     2010-01-10        23:15:00                            SIM
# 9  ...     2010-01-10        20:00:00                            ***
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# 1          FINALIZADA                         NaN
# 2          FINALIZADA                         NaN
# 3          FINALIZADA           A-539/CENIPA/2018
# 4          FINALIZADA                         NaN
# 5                 NaN                         NaN
# 6          FINALIZADA                         NaN
# 7          FINALIZADA          IG-028/CENIPA/2011
# 8          FINALIZADA           I-004/CENIPA/2011
# 9                 NaN                         NaN
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
# 1                            NÃO                       NaN
# 2                            NÃO                       NaN
# 3                            SIM                2019-10-28
# 4                            NÃO                       NaN
# 5                            NÃO                       NaN
# 6                            NÃO                       NaN
# 7                            SIM                2011-07-21
# 8                            SIM                2011-06-30
# 9                            NÃO                       NaN
#
#   total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                          1                     NÃO
# 1                   0                          1                     NÃO
# 2                   0                          1                     NÃO
# 3                   0                          1                     NÃO
# 4                   0                          1                     NÃO
# 5                   0                          1                     NÃO
# 6                   0                          1                     SIM
# 7                   3                          1                     NÃO
# 8                   2                          1                     NÃO
# 9                   0                          1                     NÃO
#
# [10 rows x 22 columns]

# %%
#criando o schema para data
#premitir itens em branco nullable=True
schema = pa.DataFrameSchema(
columns={
    "codigo": pa.Column(pa.Int, required=False),
    "codigo_ocorrencia": pa.Column(pa.Int),
    "codigo_ocorrencia2":pa.Column(pa.Int),
    "ocorrencia_classificacao": pa.Column(pa.String),
    "ocorrencia_cidade":pa.Column(pa.String),
    "ocorrencia_cidade":pa.Column(pa.String),
    "ocorrencia_uf":pa.Column(pa.String, pa.Check.str_length(2,2)),
    "ocorrencia_dia":pa.Column(pa.DateTime),
    "ocorrencia_hora":pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'),nullable=True),
    "total_recomendacoes":pa.Column(pa.Int)
    }
)

# %%
#validando o dataFrmae
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 1995              47659               47659               47659
# 1996              47661               47661               47661
# 1997              47699               47699               47699
# 1998              47979               47979               47979
# 1999              47709               47709               47709
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# 1                  40349               40349                INCIDENTE
# 2                  40351               40351                INCIDENTE
# 3                  39527               39527                 ACIDENTE
# 4                  40324               40324                INCIDENTE
# ...                  ...                 ...                      ...
# 1995               47659               47659                 ACIDENTE
# 1996               47661               47661                 ACIDENTE
# 1997               47699               47699          INCIDENTE GRAVE
# 1998               47979               47979                 ACIDENTE
# 1999               47709               47709                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade  \
# 0                    ***                  ***      RIO DE JANEIRO
# 1                    NaN                  NaN               BELÉM
# 2                    NaN                  NaN      RIO DE JANEIRO
# 3         -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE
# 4                    NaN                  NaN             PELOTAS
# ...                  ...                  ...                 ...
# 1995         -23.506667°          -46.633889°             CAJAMAR
# 1996       -6.6294444444       -72.7055555556    ATALAIA DO NORTE
# 1997       -1.3847222222       -48.4788888889               BELÉM
# 1998                 ***                  ***          ITAPIRAPUÃ
# 1999                 NaN                  NaN             VILHENA
#
#      ocorrencia_uf  ... ocorrencia_dia ocorrencia_hora  \
# 0               RJ  ...     2010-01-03        12:00:00
# 1               PA  ...     2010-01-03        11:05:00
# 2               RJ  ...     2010-01-03        03:00:00
# 3               MT  ...     2010-01-04        17:30:00
# 4               RS  ...     2010-01-05        19:25:00
# ...            ...  ...            ...             ...
# 1995            SP  ...     2013-04-22        14:00:00
# 1996            AM  ...     2013-04-22        19:00:00
# 1997            PA  ...     2013-04-22        11:28:00
# 1998            GO  ...     2013-04-22        20:30:00
# 1999            RO  ...     2013-04-23        12:28:00
#
#      investigacao_aeronave_liberada investigacao_status  \
# 0                               SIM          FINALIZADA
# 1                               SIM          FINALIZADA
# 2                               SIM          FINALIZADA
# 3                               SIM          FINALIZADA
# 4                               SIM          FINALIZADA
# ...                             ...                 ...
# 1995                            ***               ATIVA
# 1996                            SIM          FINALIZADA
# 1997                            ***          FINALIZADA
# 1998                            ***                 NaN
# 1999                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                            ***                            NÃO
# 1                            NaN                            NÃO
# 2                            NaN                            NÃO
# 3              A-539/CENIPA/2018                            SIM
# 4                            NaN                            NÃO
# ...                          ...                            ...
# 1995           A-077/CENIPA/2013                            NÃO
# 1996           A-035/CENIPA/2013                            SIM
# 1997          IG-076/CENIPA/2013                            SIM
# 1998                         NaN                            NÃO
# 1999                         ***                            NÃO
#
#      divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                          NaN                   0                          1
# 1                          NaN                   0                          1
# 2                          NaN                   0                          1
# 3                   2019-10-28                   0                          1
# 4                          NaN                   0                          1
# ...                        ...                 ...                        ...
# 1995                       NaN                   0                          1
# 1996                2013-08-14                   2                          1
# 1997                2013-09-16                   2                          1
# 1998                       NaN                   0                          1
# 1999                       NaN                   0                          1
#
#       ocorrencia_saida_pista
# 0                        NÃO
# 1                        NÃO
# 2                        NÃO
# 3                        NÃO
# 4                        NÃO
# ...                      ...
# 1995                     NÃO
# 1996                     NÃO
# 1997                     SIM
# 1998                     NÃO
# 1999                     NÃO
#
# [2000 rows x 22 columns]

# %%
#verificar tipos de dados que foram extraidos (dtypes)

df.dtypes

# %%
#arrumar a data = usar read_csv parametro parse_dates=[] (pegando o mes da data dt.month) parse só funciona se a data estiver em padrao correto
df.ocorrencia_dia.dt.month

# %% [markdown]
# ### 2º Transformação dos dados (validação dos dados)

# %%
#parametro dayfirst=True para arrumar a data pois na planilha a data é primeiro e no pandas o ultimo
#texto vazio vem NaN data vazio vem NaT
# importar lib pandera para criar schema de validação de data.
#validar itens em branco nullable=True
#validar hora com pa.Check.str_matches(expressão regular)
#validar tamnha dado ex: Uf 2 caracteres função .Check() função de restição str_length(2,2)
# validar coluna nem sempre vem ( parametro required=False) padrão coluna required true

# %% [markdown]
# ### 3º Limpeza de dados
#
# *remover * # em branco siglas incorretas etc.. *colocar um nome diferente*
# depende de cada projeto

# %%
# Out:
# 4
