# %%
import pandas as pd
df = pd.read_csv("ocorrencia.csv",nrows=2000, sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# ...

# %%
#dataframe = matriz de dados = usa função loc
#função loc = linha, coluna

df.loc[1, 'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
# df.loc[1] = linha
# df.loc[1:3] = linha x até tal
# df.loc[[10,40]] = lista duas linhas
# df.loc[:,'ocorrencia_cidade'] =todos dados da coluna
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 1995               CAJAMAR
# 1996      ATALAIA DO NORTE
# 1997                 BELÉM
# 1998            ITAPIRAPUÃ
# 1999               VILHENA
# Name: ocorrencia_cidade, Length: 2000, dtype: object

# %%
df.codigo_ocorrencia.is_unique  #verificar se contem itens unicos
# Out:
# True

# %%
df.set_index('codigo_ocorrencia', inplace=True) #alterar o label indice

# %%
df.head()
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 40211                           40211               40211               40211
# 40349                           40349               40349               40349
# 40351                           40351               40351               40351
# 39527                           39527               39527               39527
# 40324                           40324               40324               40324
#
#                    codigo_ocorrencia4 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                   ocorrencia_latitude ocorrencia_longitude  \
# ...

# %%
df.loc[40324]
# Out:
# codigo_ocorrencia1                              40324
# codigo_ocorrencia2                              40324
# codigo_ocorrencia3                              40324
# codigo_ocorrencia4                              40324
# ocorrencia_classificacao                    INCIDENTE
# ocorrencia_latitude                               NaN
# ocorrencia_longitude                              NaN
# ocorrencia_cidade                             PELOTAS
# ocorrencia_uf                                      RS
# ocorrencia_pais                                BRASIL
# ocorrencia_aerodromo                             SBPK
# ocorrencia_dia                    2010-01-05 00:00:00
# ocorrencia_hora                              19:25:00
# investigacao_aeronave_liberada                    SIM
# investigacao_status                        FINALIZADA
# divulgacao_relatorio_numero                       NaN
# divulgacao_relatorio_publicado                    NÃO
# ...

# %%
df.reset_index(drop=True, inplace=True) #revertendo o index como de inicio

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1               40349               40349               40349
# 2               40351               40351               40351
# 3               39527               39527               39527
# 4               40324               40324               40324
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE                 ***
# 1               40349                INCIDENTE                 NaN
# 2               40351                INCIDENTE                 NaN
# 3               39527                 ACIDENTE      -13.1066666667
# 4               40324                INCIDENTE                 NaN
#
#   ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***      RIO DE JANEIRO            RJ          BRASIL  ...
# ...

# %%
 #apagando dados da linha 0 coluna aerodromo df.loc[0,'ocorrencia_aerodromo']
#todos dados da linha = df.loc[1]=20
#df.loc[:,'total_recomendacoes'] = 10 # alterando todos as linhas de tal coluna

df.loc[0,'ocorrencia_aerodromo'] = ''

# %%
df.head(1)
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***    RIO DE JANEIRO            RJ          BRASIL  ...
#
#   ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0     2010-01-03        12:00:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
#
#   total_recomendacoes  total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                           1                     NÃO
#
# [1 rows x 21 columns]

# %%
#criando o backup de uma coluna
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1               40349               40349               40349
# 2               40351               40351               40351
# 3               39527               39527               39527
# 4               40324               40324               40324
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE
# 1               40349                INCIDENTE                 NaN
# 2               40351                INCIDENTE                 NaN
# 3               39527                 ACIDENTE      -13.1066666667
# 4               40324                INCIDENTE                 NaN
#
#   ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***      RIO DE JANEIRO            RJ          BRASIL  ...
# ...

# %%
#alterando a coluna ocorrencia pra GRave apenas onde a linha UF = SP
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
#localizando apenas as ocorrencias de SP
df.loc[df.ocorrencia_uf=='SP']
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 11                 40069               40069               40069
# 16                 39809               39809               39809
# 18                 39828               39828               39828
# 26                 39847               39847               39847
# 27                 39768               39768               39768
# ...                  ...                 ...                 ...
# 1983               47665               47665               47665
# 1986               47762               47762               47762
# 1988               47651               47651               47651
# 1993               47697               47697               47697
# 1995               47659               47659               47659
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 11                 40069                    GRAVE      -23.5069444444
# ...

# %% [raw]
# LImpando os dados: procurar os dados que nao foram informados
# ocorrencia_uf
# **
# ocorrencia_aerodromo
# ###!
# ####
# ****
# *****
# ocorrencia_hora
# NULL

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1               40349               40349               40349
# 2               40351               40351               40351
# 3               39527               39527               39527
# 4               40324               40324               40324
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE
# 1               40349                INCIDENTE                 NaN
# 2               40351                INCIDENTE                 NaN
# 3               39527                 ACIDENTE      -13.1066666667
# 4               40324                INCIDENTE                 NaN
#
#   ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***      RIO DE JANEIRO            RJ          BRASIL  ...
# ...

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1               40349               40349               40349
# 2               40351               40351               40351
# 3               39527               39527               39527
# 4               40324               40324               40324
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE
# 1               40349                INCIDENTE                 NaN
# 2               40351                INCIDENTE                 NaN
# 3               39527                 ACIDENTE      -13.1066666667
# 4               40324                INCIDENTE                 NaN
#
#   ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***      RIO DE JANEIRO            RJ          BRASIL  ...
# ...

# %%
#funcao replace = mundado todos os itens invalidos por pd.NA
df.replace(['###!','****','***','####','*****','NULL'], pd.NA, inplace=True)

# %%
df.isna() #mostrar tudo que não tem dado informado 
df.isna().sum() #somando todos na  isna ou isnull
# Out:
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               1406
# ocorrencia_longitude              1408
# ocorrencia_cidade                    0
# ocorrencia_uf                        0
# ocorrencia_pais                      0
# ocorrencia_aerodromo               928
# ocorrencia_dia                       0
# ocorrencia_hora                      0
# investigacao_aeronave_liberada    1148
# investigacao_status                118
# divulgacao_relatorio_numero       1254
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         1422
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# ocorrencia_uf_bkp                    0
# dtype: int64

# %%
#colocar algum valor todos os dados nao informado
df.fillna(10, inplace=True) # inplace muda o data set sem inplace só em tempo de execução

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia1                0
# codigo_ocorrencia2                0
# codigo_ocorrencia3                0
# codigo_ocorrencia4                0
# ocorrencia_classificacao          0
# ocorrencia_latitude               0
# ocorrencia_longitude              0
# ocorrencia_cidade                 0
# ocorrencia_uf                     0
# ocorrencia_pais                   0
# ocorrencia_aerodromo              0
# ocorrencia_dia                    0
# ocorrencia_hora                   0
# investigacao_aeronave_liberada    0
# investigacao_status               0
# divulgacao_relatorio_numero       0
# divulgacao_relatorio_publicado    0
# divulgacao_dia_publicacao         0
# total_recomendacoes               0
# total_aeronaves_envolvidas        0
# ocorrencia_saida_pista            0
# ocorrencia_uf_bkp                 0
# dtype: int64

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1               40349               40349               40349
# 2               40351               40351               40351
# 3               39527               39527               39527
# 4               40324               40324               40324
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE
# 1               40349                INCIDENTE                  10
# 2               40351                INCIDENTE                  10
# 3               39527                 ACIDENTE      -13.1066666667
# 4               40324                INCIDENTE                  10
#
#   ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                   10      RIO DE JANEIRO            RJ          BRASIL  ...
# ...

# %%
df.replace([10], pd.NA, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               1406
# ocorrencia_longitude              1408
# ocorrencia_cidade                    0
# ocorrencia_uf                        0
# ocorrencia_pais                      0
# ocorrencia_aerodromo               928
# ocorrencia_dia                       0
# ocorrencia_hora                      0
# investigacao_aeronave_liberada    1148
# investigacao_status                118
# divulgacao_relatorio_numero       1254
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         1422
# total_recomendacoes                  2
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# ocorrencia_uf_bkp                    0
# dtype: int64

# %%
#alterar somente em alguns lugares que tem NA
df.fillna(value={'total_recomendacoes':10}, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               1406
# ocorrencia_longitude              1408
# ocorrencia_cidade                    0
# ocorrencia_uf                        0
# ocorrencia_pais                      0
# ocorrencia_aerodromo               928
# ocorrencia_dia                       0
# ocorrencia_hora                      0
# investigacao_aeronave_liberada    1148
# investigacao_status                118
# divulgacao_relatorio_numero       1254
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         1422
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# ocorrencia_uf_bkp                    0
# dtype: int64

# %%
#excluindo coluna
df.drop(['ocorrencia_uf_bkp'], axis=1, inplace=True) #muda o eixo 0 linha 1 coluna

# %%
df.head(10)
# Out:
#   codigo_ocorrencia1 codigo_ocorrencia2 codigo_ocorrencia3 codigo_ocorrencia4  \
# 0              40211              40211              40211              40211
# 1              40349              40349              40349              40349
# 2              40351              40351              40351              40351
# 3              39527              39527              39527              39527
# 4              40324              40324              40324              40324
# 5              39807              39807              39807              39807
# 6              40215              40215              40215              40215
# 7              39707              39707              39707              39707
# 8              39156              39156              39156              39156
# 9              39711              39711              39711              39711
#
#   ocorrencia_classificacao ocorrencia_latitude ocorrencia_longitude  \
# ...

# %%
#excluindo valores nao informados
#df.dropna() ##exclui tambem as linhas
df.dropna(subset=['ocorrencia_latitude'])#informar por qual coluna que procurar o NA
# Out:
#      codigo_ocorrencia1 codigo_ocorrencia2 codigo_ocorrencia3  \
# 0                 40211              40211              40211
# 3                 39527              39527              39527
# 7                 39707              39707              39707
# 8                 39156              39156              39156
# 11                40069              40069              40069
# ...                 ...                ...                ...
# 1989              47694              47694              47694
# 1994              47876              47876              47876
# 1995              47659              47659              47659
# 1996              47661              47661              47661
# 1997              47699              47699              47699
#
#      codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                 40211                INCIDENTE
# 3                 39527                 ACIDENTE      -13.1066666667
# ...

# %%
#tirando valores duplicados
df.drop_duplicates(inplace=True)
